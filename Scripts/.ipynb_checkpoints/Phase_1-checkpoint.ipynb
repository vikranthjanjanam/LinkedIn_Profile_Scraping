# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# %%
def linkedin_connect(driver_path = "C:\\Users\\vikra\\Documents\\LinkedIn_GRA\\WebDrivers\\chromedriver.exe", username_value = "vikranthjanjanam@gmail.com", password_value = "!1Vikranth"):
    # Creating a webdriver instance
    driver = webdriver.Chrome(driver_path)
    # This instance will be used to log into LinkedIn

    # Opening linkedIn's login page
    driver.get("https://linkedin.com/login")

    # waiting for the page to load
    time.sleep(5)

    # entering username
    username = driver.find_element("id", "username")

    # In case of an error, try changing the element
    # tag used here.

    # Enter Your Email Address
    username.send_keys(username_value)

    # entering password
    pword = driver.find_element("id", "password")
    # In case of an error, try changing the element
    # tag used here.

    # Enter Your Password
    pword.send_keys(password_value)    

    # Clicking on the log in button
    # Format (syntax) of writing XPath -->
    # //tagname[@attribute='value']
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    # In case of an error, try changing the
    # XPath used here.
    return driver

# %%
def get_profile_source(driver, profile_url = "https://www.linkedin.com/in/kunalshah1/"):

    driver.get(profile_url)   # this will open the link

    start = time.time()

    # will be used in the while loop
    initialScroll = 0
    finalScroll = 1000

    while True:
        driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
        # this command scrolls the window starting from
        # the pixel value stored in the initialScroll
        # variable to the pixel value stored at the
        # finalScroll variable
        initialScroll = finalScroll
        finalScroll += 1000

        # we will stop the script for 3 seconds so that
        # the data can load
        time.sleep(3)
        # You can change it as per your needs and internet speed

        end = time.time()

        # We will scroll for 20 seconds.
        # You can change it as per your needs and internet speed
        if round(end - start) > 20:
            break

    src = driver.page_source

    # Now using beautiful soup
    soup = BeautifulSoup(src, 'lxml')
    
    return soup

# %%
def get_intro(soup):
    
    # Extracting the HTML of the complete introduction box
    # that contains the name, company name, and the location
    intro = soup.find('div', {'class': 'pv-text-details__left-panel'})
    #print(intro)
    
    # Extracting the Name
    first_name = None
    last_name = None
    try:
        name_loc = intro.find("h1")
        name = name_loc.get_text().strip()
        first_name = name.split()[0]
        last_name = ' '.join(name.split()[1:]).strip()
    except Exception as e:
        print(e)
    finally:
        pass
    # strip() is used to remove any extra blank spaces
    
    # Ectracting the Gender
    # The 2nd element in the gender
    gender = None
    try:
        gender_text = intro.find_all("span", {'class': 'text-body-small'})
        gender = gender_text[0].get_text().strip()
        
        if 'He' in gender:
            gender = 'Male'
        elif 'She' in gender:
            gender = 'Female'
        else:
            gender = None
    except Exception as e:
        print(e)
    finally:
        pass
    
    location = None
    try:
        loc_text = soup.find_all("span", {'class': 'text-body-small inline t-black--light break-words'})
        location = loc_text[0].get_text().strip()
    except Exception as e:
        print(e)
    finally:
        pass
    
    intro = {
        "profile": '',
        "first_name": first_name,
        "last_name": last_name,
        "gender": gender,
        "loaction": location
    }
    
    return intro

# %%
def get_experience(soup):
    
    exp_data = None
    try:
        # Extracting the HTML of the complete introduction box
        # that contains the name, company name, and the location
        exp_data = soup.find('div', {'id': 'experience'}).parent
        #print(exp_data)

        experiences = exp_data.find_all('li', {'class': 'artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column'})

        for experience in experiences:
            exp_values = experience.find_all('span', {'aria-hidden': 'true'})
            print("Experience", exp_values)
            for value in exp_values:
                if value.parent == experience.find('span', {'class': 'mr1 t-bold'}):
                    title = value
                if value.parent == experience.find('span', {'class': 't-14 t-normal'}):
                    company = value
                if value.parent == experience.find('span', {'class': 't-14 t-normal t-black--light'}):
                    company = value
            
    except Exception as e:
        print(e)
    finally:
        pass
    
#     intro = {
#         "first_name": first_name,
#         "last_name": last_name,
#         "gender": gender,
#         "loaction": location
#     }
    print("\n")
    return exp_data

# %%
def get_education(soup):
    
    edu_data = None
    try:
        # Extracting the HTML of the complete introduction box
        # that contains the name, company name, and the location
        edu_data = soup.find('div', {'id': 'education'}).parent
        #print(exp_data)

        academics = edu_data.find_all('li', {'class': 'artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column'})

        for academia in academics:
            edu_values = academia.find_all('span', {'aria-hidden': 'true'})
            print("Education", edu_values)
            for value in edu_values:
                if value.parent == academia.find('span', {'class': 'mr1 t-bold'}):
                    title = value
                if value.parent == academia.find('span', {'class': 't-14 t-normal'}):
                    company = value
                if value.parent == academia.find('span', {'class': 't-14 t-normal t-black--light'}):
                    company = value
            
    except Exception as e:
        print(e)
    finally:
        pass
    
#     intro = {
#         "first_name": first_name,
#         "last_name": last_name,
#         "gender": gender,
#         "loaction": location
#     }
    print("\n")
    return edu_data

# %%
def scrape_linkedin_profile(driver, profile_url):
    
    source_soup = get_profile_source(driver, profile_url)

    intro = get_intro(source_soup)
    intro['profile'] = profile_url
    print(intro, "\n")
    
    experience = get_experience(source_soup)
    education = get_education(source_soup)
    
    return [intro, experience, education]

# %%
profiles = [
    "https://www.linkedin.com/in/elizabethweil",
    "https://www.linkedin.com/in/alexisohanian",
    "https://www.linkedin.com/in/davidjli",
    "https://www.linkedin.com/in/matt-holleran-291a773",
    "https://www.linkedin.com/in/reidchristian",
]

start = time.time()
driver = linkedin_connect()
for profile in profiles:
    
    p_start = time.time()
    data = scrape_linkedin_profile(driver, profile)
    p_end = time.time()
    print("\n%s Completed in: %.2f Seconds\n" % (profile, p_end - p_start))
    
end = time.time()
print("\n\nTotal Time: %.2f Seconds" % (end - start))
# Out:
# <ipython-input-2-2c54bba1dcfd>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)
# {'profile': 'https://www.linkedin.com/in/elizabethweil', 'first_name': 'Elizabeth', 'last_name': 'Weil', 'gender': None, 'loaction': 'Menlo Park, California, United States'}
#
# Experience [<span aria-hidden="true"><!-- -->Founder and Managing Director<!-- --></span>, <span aria-hidden="true"><!-- -->Scribble Ventures · Full-time<!-- --></span>, <span aria-hidden="true"><!-- -->Mar 2020 - Present · 2 yrs 5 mos<!-- --></span>, <span aria-hidden="true"><!-- -->Scribble Ventures is an early-stage venture firm that focuses on Pre-Seed through Series A. We write initial checks of up to $1M. This allows Scribble to collaborate and co-invest with angel investors and other early-stage funds, so you can bring the best partners into your round.<!-- --><br/><br/><!-- -->We’re eager to roll up our sleeves and work with you to accelerate growth, product development, partnerships, recruiting, future fundraising and more.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Investor &amp; Board Director<span class="white-space-pre"> </span></span>, <span aria-hidden="true"><!-- -->Certn<!-- --></span>, <span aria-hidden="true"><!-- -->Dec 2019 - Present · 2 yrs 8 mos<!-- --></span>, <span aria-hidden="true"><!-- -->Victoria, British Columbia, Canada<!-- --></span>, <span aria-hidden="true"><!-- -->Background checks built for the best candidate and recruiter experience. Reduce your time to hire by 80% and get results in minutes.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Investor<!-- --></span>, <span aria-hidden="true"><!-- -->Runa<!-- --></span>, <span aria-hidden="true"><!-- -->Aug 2019 - Present · 3 yrs<!-- --></span>, <span aria-hidden="true"><!-- -->Mexico City, Mexico<!-- --></span>, <span aria-hidden="true"><!-- -->Angel investor turned Scribble Ventures portfolio company (Seed). Improving the way employees work in Latin America, through a cloud-based payroll and human resources software.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Investor &amp; Early Advisor<!-- --></span>, <span aria-hidden="true"><!-- -->Warmly,<!-- --></span>, <span aria-hidden="true"><!-- -->Nov 2019 - Present · 2 yrs 9 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>, <span aria-hidden="true"><!-- -->Angel investor &amp; advisor turned Scribble Ventures portfolio company (Pre-Seed). Revenue-generating tools for customer success teams.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Investor<!-- --></span>, <span aria-hidden="true"><!-- -->TrueNorth<!-- --></span>, <span aria-hidden="true"><!-- -->Mar 2020 - Present · 2 yrs 5 mos<!-- --></span>, <span aria-hidden="true"><!-- -->New York, New York, United States<!-- --></span>, <span aria-hidden="true"><!-- -->Scribble Ventures portfolio company. Gives truckers a single place to manage their business.<!-- --></span>]
#
#
# Education [<span aria-hidden="true"><!-- -->Stanford University<!-- --></span>, <span aria-hidden="true"><!-- -->MS Management Science and Engineering (2006), BA Economics (2004), Economics, High tech entrepreneurship, studio art<!-- --></span>, <span aria-hidden="true"><!-- -->2000 - 2006<!-- --></span>, <span aria-hidden="true"><!-- -->Activities and societies: Mayfield Fellow 2003  (Mayfield Fellows Program)<!-- --><br/><br/><!-- -->Stanford Student Enterprises (2000-2003)<!-- --></span>, <span aria-hidden="true"><!-- -->Mayfield Fellow<!-- --><br/><!-- -->Director, Stanford Student Enterprises<!-- --><br/><!-- -->Triathlon team<!-- --><br/><!-- -->Buck Scholar<!-- --></span>]
# Education [<span aria-hidden="true"><!-- -->Bella Vista<!-- --></span>, <span aria-hidden="true"><!-- -->1996 - 2000<!-- --></span>, <span aria-hidden="true"><!-- -->Activities and societies: Varsity Cross Country and Track, Distance running events and poll vault (1996-2000)<!-- --><br/><br/><!-- -->Student Government: Student Body President (2000), Jr. Class President (1999), Sophomore Class President (1998)<!-- --><br/><br/><!-- -->Science Olympiad (1996-2000)<!-- --><br/><br/><!-- -->National Honor Society (1996-2000)<!-- --></span>, <span aria-hidden="true"><!-- -->Student Body President<!-- --><br/><!-- -->Captain, Cross Country and Track teams<!-- --><br/><!-- -->6-year Science Olympiad<!-- --><br/><!-- -->National Honor Society<!-- --></span>]
# Education [<span aria-hidden="true"><!-- -->Twin Lakes<!-- --></span>, <span aria-hidden="true"><!-- -->1987 - 1994<!-- --></span>, <span aria-hidden="true"><!-- -->Activities and societies: Student Government<!-- --></span>, <span aria-hidden="true"><!-- -->Electromagnet competition champion<!-- --><br/><!-- -->Best Ben Franklin in a school play<!-- --><br/><!-- -->Oh, elementary school. :)<!-- --></span>]
#
#
#
# https://www.linkedin.com/in/elizabethweil Completed in: 22.04 Seconds
#
# {'profile': 'https://www.linkedin.com/in/alexisohanian', 'first_name': 'Alexis', 'last_name': 'Ohanian Sr.', 'gender': 'Male', 'loaction': 'Miami-Fort Lauderdale Area'}
#
# Experience [<span aria-hidden="true"><!-- -->Founder<!-- --></span>, <span aria-hidden="true"><!-- -->Seven Seven Six 7️⃣7️⃣6️⃣ · Full-time<!-- --></span>, <span aria-hidden="true"><!-- -->Sep 2020 - Present · 1 yr 11 mos<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Co-founder, Managing Partner<!-- --></span>, <span aria-hidden="true"><!-- -->Initialized Capital<!-- --></span>, <span aria-hidden="true"><!-- -->Sep 2011 - Jun 2020 · 8 yrs 10 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Reddit<!-- --></span>, <span aria-hidden="true"><!-- -->15 yrs 1 mo<!-- --></span>, <span aria-hidden="true"><!-- -->Co-Founder<!-- --></span>, <span aria-hidden="true"><!-- -->Jun 2005 - Jun 2020 · 15 yrs 1 mo<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>, <span aria-hidden="true"><!-- -->All things non-technical, including mascot doodling.<!-- --></span>, <span aria-hidden="true"><!-- -->Executive Chair<!-- --></span>, <span aria-hidden="true"><!-- -->Nov 2014 - Jul 2015 · 9 mos<!-- --></span>, <span aria-hidden="true"><!-- -->Back home where it all started.<!-- --><br/><!-- -->http://www.redditblog.com/2014/11/coming-home.html<!-- --><br/><br/><!-- -->Executive chair until coming back full-time in July 2015.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Partner<!-- --></span>, <span aria-hidden="true"><!-- -->Y Combinator<!-- --></span>, <span aria-hidden="true"><!-- -->Jun 2014 - Feb 2016 · 1 yr 9 mos<!-- --></span>, <span aria-hidden="true"><!-- -->Brooklyn, NY<!-- --></span>, <span aria-hidden="true"><!-- -->Helping founders make something people love.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Co-founder, Treasurer<!-- --></span>, <span aria-hidden="true"><!-- -->Institute on Higher Awesome Studies<!-- --></span>, <span aria-hidden="true"><!-- -->Mar 2011 - Mar 2013 · 2 yrs 1 mo<!-- --></span>, <span aria-hidden="true"><!-- -->Brooklyn, NY<!-- --></span>, <span aria-hidden="true"><!-- -->I help make it rain on our non-profit's bank account.<!-- --></span>]
#
#
# Education [<span aria-hidden="true"><!-- -->University of Virginia<!-- --></span>, <span aria-hidden="true"><!-- -->B.A., History<!-- --></span>, <span aria-hidden="true"><!-- -->Aug 2001 - May 2005<!-- --></span>, <span aria-hidden="true"><!-- -->Graduated with high distinction in History, thesis titled "Is There Nothing Intelligent to Say About a Massacre?  Conflicting Contemporary Perceptions of the Bombing of Dresden."  Ask me about this (or anything from 20th century European history) sometime, if you want to excite me.<!-- --><br/><br/><!-- -->Also graduated with a B.S. (yes, a B.S.) in Commerce, concentrating in management and international business -- now I'm looking for an international business to manage.<!-- --><br/><br/><!-- -->Minored in German, but this was kind of cheating since my mom is from Hamburg.<!-- --></span>]
#
#
#
# https://www.linkedin.com/in/alexisohanian Completed in: 21.87 Seconds
#
# {'profile': 'https://www.linkedin.com/in/davidjli', 'first_name': 'David', 'last_name': 'Li', 'gender': None, 'loaction': 'San Francisco Bay Area'}
#
# Experience [<span aria-hidden="true"><!-- -->Principal<!-- --></span>, <span aria-hidden="true"><!-- -->Avanta Ventures<!-- --></span>, <span aria-hidden="true"><!-- -->2018 - Present · 4 yrs 7 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Product Operations<!-- --></span>, <span aria-hidden="true"><!-- -->Pivotal Software, Inc.<!-- --></span>, <span aria-hidden="true"><!-- -->2017 - 2018 · 1 yr<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Venture Investor<!-- --></span>, <span aria-hidden="true"><!-- -->Longitude Capital<!-- --></span>, <span aria-hidden="true"><!-- -->2014 - 2016 · 2 yrs<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Investment Banking<!-- --></span>, <span aria-hidden="true"><!-- -->Lazard<!-- --></span>, <span aria-hidden="true"><!-- -->2012 - 2014 · 2 yrs<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Private Equity<!-- --></span>, <span aria-hidden="true"><!-- -->KKR &amp; Co. Inc.<!-- --></span>, <span aria-hidden="true"><!-- -->2010 · Less than a year<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>]
#
#
# Education [<span aria-hidden="true"><!-- -->The Wharton School<!-- --></span>, <span aria-hidden="true"><!-- -->Master of Business Administration (MBA)<!-- --></span>]
# Education [<span aria-hidden="true"><!-- -->University of California, Berkeley, Haas School of Business<!-- --></span>, <span aria-hidden="true"><!-- -->B.S., Business Administration<!-- --></span>]
#
#
#
# https://www.linkedin.com/in/davidjli Completed in: 21.75 Seconds
#
# {'profile': 'https://www.linkedin.com/in/matt-holleran-291a773', 'first_name': 'Matt', 'last_name': 'Holleran', 'gender': None, 'loaction': 'Menlo Park, California, United States'}
#
# Experience [<span aria-hidden="true"><!-- -->General Partner<!-- --></span>, <span aria-hidden="true"><!-- -->Cloud Apps Capital Partners · Full-time<!-- --></span>, <span aria-hidden="true"><!-- -->May 2013 - Present · 9 yrs 3 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>, <span aria-hidden="true"><!-- -->Early stage venture capital firm focused on investing in cloud business application companies.  Entrepreneurs value 12 years of business application operating experience, 15 years of venture capital and private equity experience, a highly relevant network, and our institutional investor base.  Our goal is to help entrepreneurs build global category leading cloud business application companies.  Investments include CrowdStrike (CRWD), Zuora (ZUO), ServiceMax (GE for ~$1B), Propel, GoFormz, and DataGrail.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Venture Partner<!-- --></span>, <span aria-hidden="true"><!-- -->Emergence Capital Partners<!-- --></span>, <span aria-hidden="true"><!-- -->Nov 2007 - May 2013 · 5 yrs 7 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Mateo, CA<!-- --></span>, <span aria-hidden="true"><!-- -->Emergence Capital Partners is a Technology Enabled Services venture capital firm.  Firm investments included Yammer (Microsoft), Box (BOX), Insightly, Veeva (VEEV) and ServiceMax (GE) during my tenure.  I developed investment theses, led investments, and served as a Board member.     Sourced and championed the first $2M investment in ServiceMax, served as a board member and recruited the CEO.  GE acquired ServiceMax for ~$1B.  Sourced and led the firm's first $3M investment in Insightly and was the Series A board member.  Sourced and served as the board observer for Box for years.   I started and led the firm's Business Freemium strategy.  Responsible for the firm's business relationships with salesforce.com, Google, Adobe, Intuit, and PayPal.  Led the firm's marketing communications for years.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->VP AppExchange and Force.com Platform Partners<!-- --></span>, <span aria-hidden="true"><!-- -->salesforce.com<!-- --></span>, <span aria-hidden="true"><!-- -->Jul 2005 - Jul 2007 · 2 yrs 1 mo<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco, CA<!-- --></span>, <span aria-hidden="true"><!-- -->The AppExchange was the world's first business applications marketplace and Force.com was the world's first enterprise grade PaaS.  My AppExchange and Force.com Partner Team was responsible for all partner facing processes from inception. We created the organization, programs and processes to drive the commercial success of the partners on the AppExchange and in their broader relationship with salesforce.com on a global basis. The AppExchange went from zero to nearly one thousand applications on the marketplace during our tenure. More importantly, the AppExchange helped to accelerate the success of what are now SaaS market leaders. Force.com was the first enterprise grade PaaS. My team worked with many companies who built their applications on the Force.com platform and helped them to leverage the salesforce.com customer base and ecosystem.  As a result, I am fortunate to have built a strong network of SaaS executives who partnered with salesforce.com and worked with my AppExchange and Force.com Partner team.  I and we have worked with a number of public and late stage cloud companies on their platform, ISV ecosystem, and marketplace strategies.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->CEO<!-- --></span>, <span aria-hidden="true"><!-- -->Apexon, Inc.<!-- --></span>, <span aria-hidden="true"><!-- -->Feb 2002 - Jun 2004 · 2 yrs 5 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Jose, CA<!-- --></span>, <span aria-hidden="true"><!-- -->CEO of Supplier Relationship Management software company serving large industrial customers like Caterpillar, Honeywell and Siemens.  Acquired by Symphony Technology Group (STG).  STG is led by Dr. Romesh Wadhwani, the former CEO of Aspect Development (acquired by i2 for $9B) and an expert in supply chain software.  Investors in Apexon were Tom Bredt of Menlo Ventures, Jim Breyer of Accel, and Dave Stamm the former founder and CEO of Clarify.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->VP Marketing and Business Development<!-- --></span>, <span aria-hidden="true"><!-- -->Datasweep<!-- --></span>, <span aria-hidden="true"><!-- -->Jan 1999 - Feb 2002 · 3 yrs 2 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Jose, CA<!-- --></span>, <span aria-hidden="true"><!-- -->Datasweep was the first to market and the market leader in browser based manufacturing and analytics applications.  I joined as the tenth employee and first non engineer when there were no customers.  Responsible for selling the first 6 customers and all marketing, product marketing, business development and partnerships (Agile).  The company was the market leader in the contract manufacturing (Flextronics, Solectron, Sanmina), telecommunications (Lucent, optical networking), and Medical Device industries (General Electric, Johnson &amp; Johnson, Depuy, Intuitive Surgical).  Rockwell Automation, a world leader in industrial automation, acquired the company.  Investors included Nancy Schoendorf of Mohr Davidow Ventures (MDV), Jim Breyer of Accel, and Roger McNamee of Integral Capital.<!-- --></span>]
#
#
# Education [<span aria-hidden="true"><!-- -->Harvard Business School<!-- --></span>, <span aria-hidden="true"><!-- -->MBA, General Management<!-- --></span>, <span aria-hidden="true"><!-- -->1991 - 1993<!-- --></span>]
# Education [<span aria-hidden="true"><!-- -->Dartmouth College<!-- --></span>, <span aria-hidden="true"><!-- -->BA, Engineering and Economics<!-- --></span>, <span aria-hidden="true"><!-- -->1985 - 1989<!-- --></span>, <span aria-hidden="true"><!-- -->Grade: Cum Laude<!-- --></span>, <span aria-hidden="true"><!-- -->Activities and societies: Walk-on Captain of the Division I Varsity Lacrosse Team.  Tom Dent Award.  Freshman Football.  Paid for education and worked two jobs.  Co-founder of Wheelock Books. Theta Delta Chi.  Member of Men's Lacrosse Leadership Group.  Started Technology Careers for Student Athletes.<!-- --></span>]
# Education [<span aria-hidden="true"><!-- -->Landon School<!-- --></span>, <span aria-hidden="true"><!-- -->High School<!-- --></span>, <span aria-hidden="true"><!-- -->1982 - 1985<!-- --></span>, <span aria-hidden="true"><!-- -->Activities and societies: Board Member 2019-?.   Headmaster's Award. Captain of the IAC DC Metro Area Lacrosse Champions.  All American.  South Team.  Varsity Football.  Scholarship kid.<!-- --></span>]
#
#
#
# https://www.linkedin.com/in/matt-holleran-291a773 Completed in: 21.78 Seconds
#
# {'profile': 'https://www.linkedin.com/in/reidchristian', 'first_name': 'Reid', 'last_name': 'Christian', 'gender': None, 'loaction': 'San Francisco Bay Area'}
#
# Experience [<span aria-hidden="true"><!-- -->General Partner<!-- --></span>, <span aria-hidden="true"><!-- -->CRV<!-- --></span>, <span aria-hidden="true"><!-- -->2017 - Present · 5 yrs 7 mos<!-- --></span>, <span aria-hidden="true"><!-- -->San Francisco Bay Area<!-- --></span>, <span aria-hidden="true"><!-- -->CRV (Charles River Ventures) is an early-stage venture capital firm that has backed over 500 startups in its 50-year history, including Airtable, Doordash, HubSpot, Patreon, Postman, Twitter and Zendesk.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Board Member<!-- --></span>, <span aria-hidden="true"><!-- -->Vercel<!-- --></span>, <span aria-hidden="true"><!-- -->2017 - Present · 5 yrs 7 mos<!-- --></span>, <span aria-hidden="true"><!-- -->The easiest way to deploy apps and sites; supporters of Next.js<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Board Member<!-- --></span>, <span aria-hidden="true"><!-- -->Fleet Device Management<!-- --></span>, <span aria-hidden="true"><!-- -->2021 - Present · 1 yr 7 mos<!-- --></span>, <span aria-hidden="true"><!-- -->Open source device management for laptops and servers (Linux, macOS, Windows), built on osquery.<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Board Member<!-- --></span>, <span aria-hidden="true"><!-- -->Tinybird<!-- --></span>, <span aria-hidden="true"><!-- -->2021 - Present · 1 yr 7 mos<!-- --></span>, <span aria-hidden="true"><!-- -->The way to build realtime data products<!-- --></span>]
# Experience [<span aria-hidden="true"><!-- -->Board Observer<!-- --></span>, <span aria-hidden="true"><!-- -->Tailscale<!-- --></span>, <span aria-hidden="true"><!-- -->2022 - Present · 7 mos<!-- --></span>, <span aria-hidden="true"><!-- -->A frustratingly simple VPN. Secure and simple.<!-- --></span>]
#
#
# Education [<span aria-hidden="true"><!-- -->Bates College<!-- --></span>, <span aria-hidden="true"><!-- -->Bachelor of Arts, Economics<!-- --></span>, <span aria-hidden="true"><!-- -->Basketball Team Captain<!-- --><br/><!-- -->Bates Young Entrepreneurs<!-- --></span>]
# Education [<span aria-hidden="true"><!-- -->Nanjing Normal University<!-- --></span>, <span aria-hidden="true"><!-- -->5-week study-abroad program in Chinese language, history and culture<!-- --></span>]
#
#
#
# https://www.linkedin.com/in/reidchristian Completed in: 21.76 Seconds
#
#
#
# Total Time: 117.56 Seconds
