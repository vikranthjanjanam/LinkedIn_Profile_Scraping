# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# %%
def linkedin_connect(driver_path = "C:\\Users\\vikra\\Documents\\LinkedIn_GRA\\WebDrivers\\chromedriver.exe", username_value = "vikranthjanjanam@gmail.com", password_value = "!1Vikranth"):
    # Creating a webdriver instance
    driver = webdriver.Chrome(driver_path)
    # This instance will be used to log into LinkedIn

    # Opening linkedIn's login page
    driver.get("https://linkedin.com/login")

    # waiting for the page to load
    time.sleep(5)

    # entering username
    username = driver.find_element("id", "username")

    # In case of an error, try changing the element
    # tag used here.

    # Enter Your Email Address
    username.send_keys(username_value)

    # entering password
    pword = driver.find_element("id", "password")
    # In case of an error, try changing the element
    # tag used here.

    # Enter Your Password
    pword.send_keys(password_value)    

    # Clicking on the log in button
    # Format (syntax) of writing XPath -->
    # //tagname[@attribute='value']
    driver.find_element(By.XPATH, "//button[@type='submit']").click()
    # In case of an error, try changing the
    # XPath used here.
    return driver

# %%
def get_profile_source(driver, profile_url = "https://www.linkedin.com/in/kunalshah1/"):

    driver.get(profile_url)   # this will open the link

    start = time.time()

    # will be used in the while loop
    initialScroll = 0
    finalScroll = 1000

    while True:
        driver.execute_script(f"window.scrollTo({initialScroll}, {finalScroll})")
        # this command scrolls the window starting from
        # the pixel value stored in the initialScroll
        # variable to the pixel value stored at the
        # finalScroll variable
        initialScroll = finalScroll
        finalScroll += 1000

        # we will stop the script for 3 seconds so that
        # the data can load
        time.sleep(3)
        # You can change it as per your needs and internet speed

        end = time.time()

        # We will scroll for 20 seconds.
        # You can change it as per your needs and internet speed
        if round(end - start) > 20:
            break

    src = driver.page_source

    # Now using beautiful soup
    soup = BeautifulSoup(src, 'lxml')
    
    return soup

# %%
def get_intro(soup):
    
    # Extracting the HTML of the complete introduction box
    # that contains the name, company name, and the location
    intro = soup.find('div', {'class': 'pv-text-details__left-panel'})
    #print(intro)
    
    # Extracting the Name
    first_name = None
    last_name = None
    try:
        name_loc = intro.find("h1")
        name = name_loc.get_text().strip()
        first_name = name.split()[0]
        last_name = ' '.join(name.split()[1:]).strip()
    except Exception as e:
        print(e)
    finally:
        pass
    # strip() is used to remove any extra blank spaces
    
    # Ectracting the Gender
    # The 2nd element in the gender
    gender = None
    try:
        gender_text = intro.find_all("span", {'class': 'text-body-small'})
        gender = gender_text[0].get_text().strip()
        
        if 'He' in gender:
            gender = 'Male'
        elif 'She' in gender:
            gender = 'Female'
        else:
            gender = None
    except Exception as e:
        print(e)
    finally:
        pass
    
    location = None
    try:
        loc_text = soup.find_all("span", {'class': 'text-body-small inline t-black--light break-words'})
        location = loc_text[0].get_text().strip()
    except Exception as e:
        print(e)
    finally:
        pass
    
    intro = {
        "profile": '',
        "first_name": first_name,
        "last_name": last_name,
        "gender": gender,
        "loaction": location
    }
    
    return intro

# %%
def get_experience(soup):
    
    exp_data = None
    try:
        # Extracting the HTML of the complete introduction box
        # that contains the name, company name, and the location
        exp_data = soup.find('div', {'id': 'experience'}).parent
        #print(exp_data)

        experiences = exp_data.find_all('li', {'class': 'artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column'})

        for experience in experiences:
            exp_values = experience.find_all('span', {'aria-hidden': 'true'})
            
            title, company, work_type, from_date, till_date, active, duration, location, details = None, None, None, None, None, None, None, None, None
            for value in exp_values:
                if value.parent == experience.find('span', {'class': 'mr1 t-bold'}):
                    title = value.get_text().strip()
                elif value.parent == experience.find('span', {'class': 't-14 t-normal'}):
                    company = str(value.get_text().strip())
                    
                    try:
                        work_type = company.split(' · ')[-1]
                        company = " ".join(company.split(' · ')[0:-1])
                    except Exception as e:
                        print(e)
                elif value.parent == experience.find('span', {'class': 't-14 t-normal t-black--light'}):
                    value = value.get_text().strip()
                    try:
                        period = value.split(' · ')[0]
                        duration = value.split(' · ')[1]
                        
                        from_date = period.split(' - ')[0]
                        till_date = period.split(' - ')[1]
                        
                        if till_date.strip() == "Present":
                            active = True
                            till_date = None
                        
                    except Exception as e:
                        print(e)
                        location = value
                
                elif value.parent == experience.find('div', {'class': 'inline-show-more-text inline-show-more-text--is-collapsed'}):
                    details = value.get_text().strip()
                        
            experience_details = {
                "profile": "",
                "title": title,
                "company": company,
                "work_type": work_type,
                "from_date": from_date,
                "till_date": till_date,
                "active": active,
                "duration": duration,
                "location": location,
                "details": details
            }
            print(experience_details)
            
    except Exception as e:
        print(e)
    finally:
        pass
    
#     intro = {
#         "first_name": first_name,
#         "last_name": last_name,
#         "gender": gender,
#         "loaction": location
#     }
    print("\n")
    return exp_data

# %%
def get_education(soup):
    
    edu_data = None
    try:
        # Extracting the HTML of the complete introduction box
        # that contains the name, company name, and the location
        edu_data = soup.find('div', {'id': 'education'}).parent
        #print(exp_data)

        academics = edu_data.find_all('li', {'class': 'artdeco-list__item pvs-list__item--line-separated pvs-list__item--one-column'})

        for academia in academics:
            edu_values = academia.find_all('span', {'aria-hidden': 'true'})
            print("Education", edu_values)
            for value in edu_values:
                if value.parent == academia.find('span', {'class': 'mr1 t-bold'}):
                    title = value.get_text().strip()
                if value.parent == academia.find('span', {'class': 't-14 t-normal'}):
                    company = value.get_text().strip()
                if value.parent == academia.find('span', {'class': 't-14 t-normal t-black--light'}):
                    company = value.get_text().strip()
            
    except Exception as e:
        print(e)
    finally:
        pass
    
#     intro = {
#         "first_name": first_name,
#         "last_name": last_name,
#         "gender": gender,
#         "loaction": location
#     }
    print("\n")
    return edu_data

# %%
def scrape_linkedin_profile(driver, profile_url):
    
    source_soup = get_profile_source(driver, profile_url)

    intro = get_intro(source_soup)
    intro['profile'] = profile_url
    print(intro, "\n")
    
    experience = get_experience(source_soup)
    education = get_education(source_soup)
    
    return [intro, experience, education]

# %%
profiles = [
    "https://www.linkedin.com/in/elizabethweil",
    "https://www.linkedin.com/in/alexisohanian",
    "https://www.linkedin.com/in/davidjli",
    "https://www.linkedin.com/in/matt-holleran-291a773",
    "https://www.linkedin.com/in/reidchristian",
]

start = time.time()
driver = linkedin_connect()
for profile in profiles:
    
    p_start = time.time()
    data = scrape_linkedin_profile(driver, profile)
    p_end = time.time()
    print("\n%s Completed in: %.2f Seconds\n" % (profile, p_end - p_start))
    
end = time.time()
print("\n\nTotal Time: %.2f Seconds" % (end - start))
# Out:
# <ipython-input-2-2c54bba1dcfd>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)
# 'NoneType' object has no attribute 'find'
# 'NoneType' object has no attribute 'find_all'
# list index out of range
# {'profile': 'https://www.linkedin.com/in/elizabethweil', 'first_name': None, 'last_name': None, 'gender': None, 'loaction': None}
#
# 'NoneType' object has no attribute 'parent'
#
#
# 'NoneType' object has no attribute 'parent'
#
#
#
# https://www.linkedin.com/in/elizabethweil Completed in: 21.41 Seconds
#
# 'NoneType' object has no attribute 'find'
# 'NoneType' object has no attribute 'find_all'
# list index out of range
# {'profile': 'https://www.linkedin.com/in/alexisohanian', 'first_name': None, 'last_name': None, 'gender': None, 'loaction': None}
#
# 'NoneType' object has no attribute 'parent'
#
#
# 'NoneType' object has no attribute 'parent'
#
#
#
# https://www.linkedin.com/in/alexisohanian Completed in: 21.56 Seconds
#
# 'NoneType' object has no attribute 'find'
# 'NoneType' object has no attribute 'find_all'
# list index out of range
# {'profile': 'https://www.linkedin.com/in/davidjli', 'first_name': None, 'last_name': None, 'gender': None, 'loaction': None}
#
# 'NoneType' object has no attribute 'parent'
#
#
# 'NoneType' object has no attribute 'parent'
#
#
#
# https://www.linkedin.com/in/davidjli Completed in: 21.56 Seconds
