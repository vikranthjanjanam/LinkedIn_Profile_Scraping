# %%
# %run Phase_1.ipynb

# %%
comp_df = pd.read_csv(r"C:/Users/vikra/Documents/LinkedIn_GRA/Data/Results/company_links_2022.07.18_02.02.csv")

comp_df.head()
# Out:
#              company                                         comp_link
# 0  Scribble Ventures  https://www.linkedin.com/company/67207357/about/
# 1              Certn  https://www.linkedin.com/company/17891142/about/
# 2               Runa  https://www.linkedin.com/company/22316561/about/
# 3            Warmly,  https://www.linkedin.com/company/30583455/about/
# 4          TrueNorth  https://www.linkedin.com/company/10665055/about/

# %%
company_scrapper(comp_df)
# Out:
# <ipython-input-1-e7729c0e58e1>:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)
# https://www.linkedin.com/company/67207357/about/ Completed in: 19.09 Seconds
#
#
# https://www.linkedin.com/company/17891142/about/ Completed in: 19.11 Seconds
#
#
# https://www.linkedin.com/company/22316561/about/ Completed in: 19.16 Seconds
#
#
# https://www.linkedin.com/company/30583455/about/ Completed in: 19.15 Seconds
#
#
# https://www.linkedin.com/company/10665055/about/ Completed in: 19.11 Seconds
#
#
# https://www.linkedin.com/company/52160608/about/ Completed in: 19.42 Seconds
#
#
# https://www.linkedin.com/company/11249478/about/ Completed in: 19.19 Seconds
#
#
# https://www.linkedin.com/company/1791/about/ Completed in: 19.50 Seconds
#
#
# https://www.linkedin.com/company/42352720/about/ Completed in: 19.43 Seconds
#
#
# https://www.linkedin.com/company/3724/about/ Completed in: 19.53 Seconds
#
#
# ...

# %%
comp_df.shape
